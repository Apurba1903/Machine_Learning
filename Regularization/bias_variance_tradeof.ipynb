# %%
import random
import numpy as np

outcome = []

for i in range(100000):
    outcome.append(random.randint(1,6))

np.array(outcome).mean()
# Out:
# 3.50098

# %%
from mlxtend.evaluate import bias_variance_decomp
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from mlxtend.data import boston_housing_data
from sklearn.model_selection import train_test_split

X, y = boston_housing_data()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=123, shuffle=True
)

# %% [markdown]
# ### Low Variance High Bias

# %%
lr = LinearRegression()

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
    lr, X_train, y_train, X_test, y_test, loss='mse', random_seed=123
)

print('Average Expected Loss: %.3f' % avg_expected_loss)
print('Average Bias: %.3f' % avg_bias)
print('Average Variance: %.3f' % avg_var)
# Out:
# Average Expected Loss: 29.891
# Average Bias: 28.609
# Average Variance: 1.282

# %% [markdown]
# ### High Variance Low Bias

# %%
dt = DecisionTreeRegressor(random_state=123)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
    dt, X_train, y_train, X_test, y_test, loss='mse', random_seed=123
)

print('Average Expected Loss: %.3f' % avg_expected_loss)
print('Average Bias: %.3f' % avg_bias)
print('Average Variance: %.3f' % avg_var)
# Out:
# Average Expected Loss: 31.536
# Average Bias: 14.096
# Average Variance: 17.440
